# %% [markdown]
# # Initialization

# %%
import numpy as np
import pandas as pd

from sklearn import model_selection
from sklearn import linear_model

# %% [markdown]
# # Data

# %%
data = pd.read_csv('data/data.csv')

# %%
data
# Out:
#                                   depart  \
# 0                  Centre des handicapes
# 1                  Centre des handicapes
# 2                  Centre des handicapes
# 3                  Centre des handicapes
# 4                  Centre des handicapes
# 5                  Centre des handicapes
# 6                  Centre des handicapes
# 7                  Centre des handicapes
# 8                  Centre des handicapes
# 9                  Centre des handicapes
# 10                 Centre des handicapes
# 11                 Centre des handicapes
# 12                 Centre des handicapes
# 13                 Centre des handicapes
# 14                 Centre des handicapes
# 15                 Centre des handicapes
# 16                 Centre des handicapes
# 17                 Centre des handicapes
# 18                 Centre des handicapes
# 19                 Centre des handicapes
# 20                 Centre des handicapes
# 21                 Centre des handicapes
# 22                 Centre des handicapes
# 23                 Centre des handicapes
# 24                 Centre des handicapes
# 25                 Centre des handicapes
# 26                 Centre des handicapes
# 27                 Centre des handicapes
# 28                 Centre des handicapes
# 29                 Centre des handicapes
# ...                                  ...
# 1099     Eleveur (tradex college ebanda)
# 1100     Eleveur (tradex college ebanda)
# 1101                            Mvog-ada
# 1102                            Mvog-ada
# 1103                            Mvog-ada
# 1104                            Mvog-ada
# 1105                            Mvog-ada
# 1106                            Mvog-ada
# 1107                            Mvog-ada
# 1108  hotel de ville(avenue des banques)
# 1109  hotel de ville(avenue des banques)
# 1110  hotel de ville(avenue des banques)
# 1111  hotel de ville(avenue des banques)
# 1112  hotel de ville(avenue des banques)
# 1113  hotel de ville(avenue des banques)
# 1114                      TKC(carrefour)
# 1115                      TKC(carrefour)
# 1116                      TKC(carrefour)
# 1117                      TKC(carrefour)
# 1118                      TKC(carrefour)
# 1119                      Carrefour MEEC
# 1120                      Carrefour MEEC
# 1121                      Carrefour MEEC
# 1122                      Carrefour MEEC
# 1123     Mvog Atangana Mballa(pharmacie)
# 1124     Mvog Atangana Mballa(pharmacie)
# 1125     Mvog Atangana Mballa(pharmacie)
# 1126                  Ngoa Ekélé (lycée)
# 1127                  Ngoa Ekélé (lycée)
# 1128    Chateau(Université de Yaoundé I)
#
#                                     arrive distance_min  distance_max  \
# 0                            mokolo-marché          800          4100
# 1                              Total Melen         6000          9300
# 2                            Carefour EMIA          114          3414
# 3                        Bastos(carrefour)         3797          7097
# 4                               Cité verte          800          4100
# 5                               Madagascar          700          4000
# 6                                 Carriere         2200          5500
# 7                                   Bastos         4900          8200
# 8                                Nkom-kana         2800          6100
# 9                               Nkolbisson         3200          6500
# 10                                  Tsinga         2900          6200
# 11                             Briqueterie         1400          4700
# 12              Ecole de police(pharmacie)         2400          5700
# 13    Ecole des postes(immeuble cyberlink)         1000          4300
# 14                        Emombo(Chapelle)         6100          9400
# 15                     Mimboman(don bosco)         9100         12400
# 16                           Essos(marché)         5900          9200
# 17                               Omnisport         7200         10500
# 18                        Ngousso(station)         9000         12300
# 19                       Damas(rond point)         5500          8800
# 20                                 Tam-tam         3700          7000
# 21                    Nsimeyong(pharmacie)         3100          6400
# 22                         Accacia(marché)         1900          5200
# 23                          Etoudi(marché)         8200         11500
# 24                Santa barbara(cyberlink)         9300         12600
# 25                                   Emana         8900         12200
# 26              (Mission Catholique)Nkozoa        15100         18400
# 27                                Nlongkak         3900          7200
# 28                         Anguissa(lycée)         6200          9500
# 29                                 Ekounou         5000          8300
# ...                                    ...          ...           ...
# 1099      Chateau(Université de Yaoundé I)        10200         11600
# 1100                             Ekoundoum        99300        100700
# 1101    hotel de ville(avenue des banques)         3100          4500
# 1102                        TKC(carrefour)         8400          9800
# 1103                        Carrefour MEEC         6300          7700
# 1104       Mvog Atangana Mballa(pharmacie)         2300          3700
# 1105                    Ngoa Ekélé (lycée)         3600          5000
# 1106      Chateau(Université de Yaoundé I)         4500          5900
# 1107                             Ekoundoum        98400         99800
# 1108                        TKC(carrefour)         9100         10500
# 1109                        Carrefour MEEC         5800          7200
# 1110       Mvog Atangana Mballa(pharmacie)         3500          4900
# 1111                    Ngoa Ekélé (lycée)         3600          5000
# 1112      Chateau(Université de Yaoundé I)         3800          5200
# 1113                             Ekoundoum       101000        102400
# 1114                        Carrefour MEEC         4200          5600
# 1115       Mvog Atangana Mballa(pharmacie)         5800          7200
# 1116                    Ngoa Ekélé (lycée)         5800          7200
# 1117      Chateau(Université de Yaoundé I)         4800          6200
# 1118                             Ekoundoum       107000        108400
# 1119       Mvog Atangana Mballa(pharmacie)         4900          6300
# 1120                    Ngoa Ekélé (lycée)         3000          4400
# 1121      Chateau(Université de Yaoundé I)         4200          5600
# 1122                             Ekoundoum       104000        105400
# 1123                    Ngoa Ekélé (lycée)         2000          3400
# 1124      Chateau(Université de Yaoundé I)         2300          3700
# 1125                             Ekoundoum       101000        102400
# 1126      Chateau(Université de Yaoundé I)          350          1750
# 1127                             Ekoundoum       102000        103400
# 1128                             Ekoundoum       102000        103400
#
#       distance_moy  virage_min  virage_max  prix_moy
# 0             2300           7          10       225
# 1             7500           3           5       175
# 2             1614           7           9       225
# 3             5297          14          20       350
# 4             2300          10          16       275
# 5             2200          14          15       275
# 6             3700           9          11       250
# 7             6400          14          20       350
# 8             4300          14          19       300
# 9             4700          14          26       300
# 10            4400          13          15       300
# 11            2900          14          15       250
# 12            3900          17          17       250
# 13            2500           5           6       250
# 14            7600           5           9       375
# 15           10600          13          15       450
# 16            7400           7          10       300
# 17            8700          11          13       350
# 18           10500           8          13       400
# 19            7000           5          11       250
# 20            5200           4          12       225
# 21            4600           4          11       250
# 22            3400           4           8       150
# 23            9700           8          14       400
# 24           10800          14          17       400
# 25           10400           7          13       300
# 26           16600           7           7       300
# 27            5400           8          12       375
# 28            7700           8          11       450
# 29            6500           8          13       450
# ...            ...         ...         ...       ...
# 1099         10200          17          20       250
# 1100         99300          27          30      1200
# 1101          3100          10          12       250
# 1102          8400          18          25       300
# 1103          6300           9          13       250
# 1104          2300           7           8       175
# 1105          3600           9          15       250
# 1106          4500           9          15       250
# 1107         98400          21          24      1250
# 1108          9100          24          30       300
# 1109          5800          18          19       250
# 1110          3500          10          14       250
# 1111          3600          15          16       250
# 1112          3800          15          16       250
# 1113        101000          20          25      1200
# 1114          4200          12          12       250
# 1115          5800          23          23       250
# 1116          5800          13          16       250
# 1117          4800          13          16       250
# 1118        107000          32          36      1400
# 1119          4900          14          14       250
# 1120          3000          10          11       250
# 1121          4200          10          11       250
# 1122        104000          23          30      1300
# 1123          2000           8           9       150
# 1124          2300           9          10       150
# 1125        101000          20          27      1300
# 1126           350           1           1       100
# 1127        102000          13          14       400
# 1128        102000          23          25      1400
#
# [1129 rows x 8 columns]

# %%
data = data[['distance_min', 'virage_min', 'prix_moy']]
data.columns = ['distance', 'virage', 'prix']
data
# Out:
#      distance  virage  prix
# 0         800       7   225
# 1        6000       3   175
# 2         114       7   225
# 3        3797      14   350
# 4         800      10   275
# 5         700      14   275
# 6        2200       9   250
# 7        4900      14   350
# 8        2800      14   300
# 9        3200      14   300
# 10       2900      13   300
# 11       1400      14   250
# 12       2400      17   250
# 13       1000       5   250
# 14       6100       5   375
# 15       9100      13   450
# 16       5900       7   300
# 17       7200      11   350
# 18       9000       8   400
# 19       5500       5   250
# 20       3700       4   225
# 21       3100       4   250
# 22       1900       4   150
# 23       8200       8   400
# 24       9300      14   400
# 25       8900       7   300
# 26      15100       7   300
# 27       3900       8   375
# 28       6200       8   450
# 29       5000       8   450
# ...       ...     ...   ...
# 1099    10200      17   250
# 1100    99300      27  1200
# 1101     3100      10   250
# 1102     8400      18   300
# 1103     6300       9   250
# 1104     2300       7   175
# 1105     3600       9   250
# 1106     4500       9   250
# 1107    98400      21  1250
# 1108     9100      24   300
# 1109     5800      18   250
# 1110     3500      10   250
# 1111     3600      15   250
# 1112     3800      15   250
# 1113   101000      20  1200
# 1114     4200      12   250
# 1115     5800      23   250
# 1116     5800      13   250
# 1117     4800      13   250
# 1118   107000      32  1400
# 1119     4900      14   250
# 1120     3000      10   250
# 1121     4200      10   250
# 1122   104000      23  1300
# 1123     2000       8   150
# 1124     2300       9   150
# 1125   101000      20  1300
# 1126      350       1   100
# 1127   102000      13   400
# 1128   102000      23  1400
#
# [1129 rows x 3 columns]

# %%
X, y = data[['distance', 'virage']], data['prix']

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.2)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (903, 2) (903,)
# (226, 2) (226,)

# %% [markdown]
# # Linear regression

# %%
lin_reg = linear_model.LinearRegression()

model = lin_reg.fit(X_train, y_train)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (136.62932121754531, array([ 0.00917851,  7.83770367]))

# %%
predictions = lin_reg.predict(X_test)
predictions
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-21ad29a24d85> in <module>()
# ----> 1 predictions = lin_reg.predict(X_test)
#       2 predictions
#
# /usr/local/lib/python3.4/dist-packages/sklearn/linear_model/base.py in predict(self, X)
#     266             Returns predicted values.
#     267         """
# --> 268         return self._decision_function(X)
#     269
#     270     _preprocess_data = staticmethod(_preprocess_data)
#
# /usr/local/lib/python3.4/dist-packages/sklearn/linear_model/base.py in _decision_function(self, X)
#     249         check_is_fitted(self, "coef_")
#     250
# --> 251         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     252         return safe_sparse_dot(X, self.coef_.T,
#     253                                dense_output=True) + self.intercept_
#
# /usr/local/lib/python3.4/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     400         # make sure we actually converted to numeric:
#     401         if dtype_numeric and array.dtype.kind == "O":
# --> 402             array = array.astype(np.float64)
#     403         if not allow_nd and array.ndim >= 3:
#     404             raise ValueError("Found array with dim %d. %s expected <= 2."
#
# ValueError: could not convert string to float: 'Err:520'
